# %% [markdown]
# # Exploratory Data Analysis Notebook Introduction
#
# In this notebook, I will guide you through fundamental approaches to address key aspects of the data analysis process, including feature engineering, feature selection, handling imbalanced data, and model parameter optimization.
#
# ## Objectives:
#
# 1. **Feature Engineering:**
#    Explore techniques to enhance the representation of features, potentially improving the model's performance.
#
# 2. **Feature Selection:**
#    Discuss methods for selecting the most relevant features, ensuring a more focused and efficient model.
#
# 3. **Handling Imbalanced Data:**
#    Address the challenges posed by imbalanced datasets, with a focus on strategies to mitigate bias and improve model robustness.
#
# 4. **Model Parameter Search:**
#    Walk through the process of optimizing model parameters, aiming to enhance the overall predictive capabilities.
#
# By the end of this notebook, you should have a foundational understanding of these essential aspects of data analysis, providing a solid framework for further exploration and refinement of your models.

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

# %%
test_data = pd.read_csv("../data/test.csv", index_col="index", low_memory=False)
train_data = pd.read_csv("../data/train.csv", index_col="index", low_memory=False)

# %%
### How large is the training data set and the test data set?
print("test data size: ", test_data.shape)
print("train data size: ", train_data.shape)
# Out:
# test data size:  (171843, 62)
# train data size:  (687369, 63)

# %%
### train data
train_data.target__office.value_counts()
# Out:
# target__office
# False    681787
# True       5582
# Name: count, dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 687369 entries, 574546 to 460554
# Data columns (total 63 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   borough               687369 non-null  object
#  1   block                 687369 non-null  int64
#  2   lot                   687369 non-null  int64
#  3   schooldist            685166 non-null  float64
#  4   council               684952 non-null  float64
#  5   zipcode               684042 non-null  float64
#  6   firecomp              684565 non-null  object
#  7   policeprct            684997 non-null  float64
#  8   healthcenterdistrict  685243 non-null  float64
#  9   healtharea            684720 non-null  float64
#  10  sanitboro             682276 non-null  float64
#  11  sanitdistrict         682304 non-null  float64
#  12  sanitsub              674668 non-null  object
#  13  zonedist1             686563 non-null  object
#  14  zonedist2             15888 non-null   object
#  15  zonedist3             149 non-null     object
#  16  zonedist4             11 non-null      object
#  17  overlay1              59819 non-null   object
#  18  overlay2              125 non-null     object
#  19  spdist1               81519 non-null   object
#  20  spdist2               54 non-null      object
#  21  spdist3               0 non-null       float64
#  22  ltdheight             2419 non-null    object
#  23  splitzone             686563 non-null  object
#  24  landuse               685076 non-null  float64
#  25  easements             687369 non-null  int64
#  26  lotarea               687369 non-null  int64
#  27  bldgarea              687369 non-null  int64
#  28  comarea               687369 non-null  int64
#  29  resarea               687369 non-null  int64
#  30  officearea            687369 non-null  int64
#  31  retailarea            687369 non-null  int64
#  32  garagearea            687369 non-null  int64
#  33  strgearea             687369 non-null  int64
#  34  factryarea            687369 non-null  int64
#  35  otherarea             687369 non-null  int64
#  36  numbldgs              687369 non-null  int64
#  37  numfloors             687369 non-null  float64
#  38  unitstotal            687369 non-null  int64
#  39  lotfront              687369 non-null  float64
#  40  lotdepth              687369 non-null  float64
#  41  bldgfront             687369 non-null  float64
#  42  bldgdepth             687369 non-null  float64
#  43  ext                   280056 non-null  object
#  44  proxcode              686972 non-null  float64
#  45  irrlotcode            686972 non-null  object
#  46  lottype               686972 non-null  float64
#  47  bsmtcode              686972 non-null  float64
#  48  assessland            687369 non-null  int64
#  49  assesstot             687369 non-null  int64
#  50  exemptland            687369 non-null  int64
#  51  exempttot             687369 non-null  int64
#  52  yearbuilt             687369 non-null  int64
#  53  yearalter1            687369 non-null  int64
#  54  yearalter2            687369 non-null  int64
#  55  histdist              23866 non-null   object
#  56  landmark              1260 non-null    object
#  57  builtfar              687369 non-null  float64
#  58  tract2010             687369 non-null  int64
#  59  xcoord                668158 non-null  float64
#  60  ycoord                668158 non-null  float64
#  61  zonemap               686582 non-null  object
#  62  target__office        687369 non-null  bool
# dtypes: bool(1), float64(21), int64(23), object(18)
# memory usage: 331.0+ MB

# %%
categorical_features = train_data.select_dtypes(include="object").columns
numerical_features = train_data.select_dtypes(include="number").columns

# %%
print("#########Categorical Features Label Count#############")
for f in categorical_features:
    print()
    print(f, len(train_data[f].dropna().unique()))
#     print(new_train_data[f].unique())

print("#########Numerical Features Unique Values Count#############")
for f in numerical_features:
    y = train_data[f].dropna()
    x = range(len(y))
    print(f, len(y.unique()))
#     plt.scatter(x, y, s=0.1)
#     plt.title(f'{f}, unique values: {len(y.unique())}')
#     plt.show()
# Out:
# #########Categorical Features Label Count#############
#
# borough 5
#
# firecomp 348
#
# sanitsub 60
#
# zonedist1 162
#
# zonedist2 145
#
# zonedist3 58
#
# zonedist4 11
#
# overlay1 10
#
# overlay2 10
#
# spdist1 78
#
# spdist2 18
#
# ltdheight 2
#
# splitzone 2
#
# ext 3
#
# irrlotcode 2
#
# histdist 137
#
# landmark 2
#
# zonemap 129
# #########Numerical Features Unique Values Count#############
# block 13915
# lot 2331
# schooldist 32
# council 51
# zipcode 208
# policeprct 77
# healthcenterdistrict 30
# healtharea 210
# sanitboro 8
# sanitdistrict 27
# spdist3 0
# landuse 11
# easements 12
# lotarea 25834
# bldgarea 32669
# comarea 17791
# resarea 24594
# officearea 7450
# retailarea 8281
# garagearea 3269
# strgearea 3100
# factryarea 2648
# otherarea 6892
# numbldgs 133
# numfloors 162
# unitstotal 701
# lotfront 13519
# lotdepth 14565
# bldgfront 4627
# bldgdepth 4651
# proxcode 4
# lottype 10
# bsmtcode 6
# assessland 53928
# assesstot 77001
# exemptland 25077
# exempttot 36877
# yearbuilt 214
# yearalter1 116
# yearalter2 74
# builtfar 2120
# tract2010 1328
# xcoord 129381
# ycoord 132302

# %%
numerical_features_new_set = [
    'easements',
    'lotarea',
    'bldgarea',
    'comarea',
    'resarea',
    'officearea',
    'retailarea',
    'garagearea',
    'strgearea',
    'factryarea',
    'otherarea',
    'numbldgs',
    'numfloors',
    'unitstotal',
    'lotfront',
    'lotdepth',
    'bldgfront',
    'bldgdepth',
    'assessland',
    'assesstot',
    'exemptland',
    'exempttot',
    'builtfar',
    'xcoord',
    'ycoord',
]


extra_categorical_features = [f for f in numerical_features if f not in numerical_features_new_set]

categorical_features = list(categorical_features) + extra_categorical_features
numerical_features = numerical_features_new_set
# drop yearalter1, yearalter2, tract2010
# train_data.yearalter1.value_counts()

# %%
for f in categorical_features:
    data = train_data[f]
    data_unique = data.dropna().unique()
    print(f"feature: {f}, unique values: {len(data_unique)}, nan values: {data.isnull().sum()}, sample_values: {data_unique[:3]}")
#     sns.histplot(data)
#     plt.title(f)
#     plt.show()
# Out:
# feature: borough, unique values: 5, nan values: 0, sample_values: ['BX' 'QN' 'BK']
# feature: firecomp, unique values: 348, nan values: 2804, sample_values: ['E096' 'E264' 'E276']
# feature: sanitsub, unique values: 60, nan values: 12701, sample_values: ['1A' '2D' '2E']
# feature: zonedist1, unique values: 162, nan values: 806, sample_values: ['R6' 'R4-1' 'R3-2']
# feature: zonedist2, unique values: 145, nan values: 671481, sample_values: ['R7-1' 'R6' 'C8-1']
# feature: zonedist3, unique values: 58, nan values: 687220, sample_values: ['C4-5X' 'C3' 'C4-7']
# feature: zonedist4, unique values: 11, nan values: 687358, sample_values: ['C1-9' 'C4-4A' 'R4']
# feature: overlay1, unique values: 10, nan values: 627550, sample_values: ['C2-4' 'C1-4' 'C1-1']
# feature: overlay2, unique values: 10, nan values: 687244, sample_values: ['C2-3' 'C1-5' 'C1-1']
# feature: spdist1, unique values: 78, nan values: 605850, sample_values: ['BR' 'SRD' 'CR']
# feature: spdist2, unique values: 18, nan values: 687315, sample_values: ['PI' '125th' 'MX-16/EC-6']
# feature: ltdheight, unique values: 2, nan values: 684950, sample_values: ['LH-1A' 'LH-1']
# feature: splitzone, unique values: 2, nan values: 806, sample_values: ['N' 'Y']
# feature: ext, unique values: 3, nan values: 407313, sample_values: ['E' 'G' 'EG']
# feature: irrlotcode, unique values: 2, nan values: 397, sample_values: ['N' 'Y']
# feature: histdist, unique values: 137, nan values: 663503, sample_values: ['Hamilton Heights/Sugar Hill Historic Dis'
#  'Madison Square North Historic District'
#  'Upper East Side Historic District']
# feature: landmark, unique values: 2, nan values: 686109, sample_values: ['INDIVIDUAL LANDMARK' 'INTERIOR LANDMARK']
# feature: zonemap, unique values: 129, nan values: 787, sample_values: ['6C' '31A' '23B']
# feature: block, unique values: 13915, nan values: 0, sample_values: [ 3717 15818  6787]
# feature: lot, unique values: 2331, nan values: 0, sample_values: [64 48  7]
# feature: schooldist, unique values: 32, nan values: 2203, sample_values: [ 8. 27. 22.]
# feature: council, unique values: 51, nan values: 2417, sample_values: [18. 31. 48.]
# feature: zipcode, unique values: 208, nan values: 3327, sample_values: [10472. 11691. 11229.]
# feature: policeprct, unique values: 77, nan values: 2372, sample_values: [ 43. 101.  61.]
# feature: healthcenterdistrict, unique values: 30, nan values: 2126, sample_values: [26. 45. 35.]
# feature: healtharea, unique values: 210, nan values: 2649, sample_values: [3020. 3800. 7320.]
# feature: sanitboro, unique values: 8, nan values: 5093, sample_values: [2. 4. 3.]
# feature: sanitdistrict, unique values: 27, nan values: 5065, sample_values: [ 9. 14. 15.]
# feature: spdist3, unique values: 0, nan values: 687369, sample_values: []
# feature: landuse, unique values: 11, nan values: 2293, sample_values: [1. 2. 4.]
# feature: proxcode, unique values: 4, nan values: 397, sample_values: [2. 1. 3.]
# feature: lottype, unique values: 10, nan values: 397, sample_values: [5. 3. 8.]
# feature: bsmtcode, unique values: 6, nan values: 397, sample_values: [2. 0. 1.]
# feature: yearbuilt, unique values: 214, nan values: 0, sample_values: [1940 1930 1910]
# feature: yearalter1, unique values: 116, nan values: 0, sample_values: [   0 1986 1949]
# feature: yearalter2, unique values: 74, nan values: 0, sample_values: [   0 1997 2005]
# feature: tract2010, unique values: 1328, nan values: 0, sample_values: [   48 99802   548]

# %%
train_data[categorical_features].isnull().sum()
# might be some meaning in nan values. each feature must be evaluated.
# Out:
# borough                      0
# firecomp                  2804
# sanitsub                 12701
# zonedist1                  806
# zonedist2               671481
# zonedist3               687220
# zonedist4               687358
# overlay1                627550
# overlay2                687244
# spdist1                 605850
# spdist2                 687315
# ltdheight               684950
# splitzone                  806
# ext                     407313
# irrlotcode                 397
# histdist                663503
# landmark                686109
# zonemap                    787
# block                        0
# lot                          0
# schooldist                2203
# council                   2417
# zipcode                   3327
# policeprct                2372
# healthcenterdistrict      2126
# healtharea                2649
# sanitboro                 5093
# sanitdistrict             5065
# spdist3                 687369
# landuse                   2293
# proxcode                   397
# lottype                    397
# bsmtcode                   397
# yearbuilt                    0
# yearalter1                   0
# yearalter2                   0
# tract2010                    0
# dtype: int64

# %%
train_data[numerical_features].isnull().sum()
# Out:
# easements         0
# lotarea           0
# bldgarea          0
# comarea           0
# resarea           0
# officearea        0
# retailarea        0
# garagearea        0
# strgearea         0
# factryarea        0
# otherarea         0
# numbldgs          0
# numfloors         0
# unitstotal        0
# lotfront          0
# lotdepth          0
# bldgfront         0
# bldgdepth         0
# assessland        0
# assesstot         0
# exemptland        0
# exempttot         0
# builtfar          0
# xcoord        19211
# ycoord        19211
# dtype: int64

# %%
bool_mask = train_data[numerical_features].isnull().sum() <= 19211
numerical_features = np.array(numerical_features)[bool_mask].tolist()

bool_mask = train_data[categorical_features].isnull().sum() <= 12701
categorical_features = np.array(categorical_features)[bool_mask].tolist()

# %%
for f in categorical_features:
    data = train_data[f]
    data_unique = data.dropna().unique()
    if 0 in data_unique:
        print(f"feature: {f}, unique values: {len(data_unique)}, zero counts: {data.value_counts()[0]}, "
              f"nan values: {data.isnull().sum()}, sample_values: {data_unique[:3]}")
    else:
        print(f"feature: {f}, unique values: {len(data_unique)}, "
              f"nan values: {data.isnull().sum()}, sample_values: {data_unique[:3]}")
    sns.histplot(data)
    plt.title(f)
    if len(data_unique) > 15 :
        plt.xticks(rotation=90)
    plt.show()
# Out:
# feature: borough, unique values: 5, nan values: 0, sample_values: ['BX' 'QN' 'BK']
# feature: firecomp, unique values: 348, nan values: 2804, sample_values: ['E096' 'E264' 'E276']
# feature: sanitsub, unique values: 60, nan values: 12701, sample_values: ['1A' '2D' '2E']
# feature: zonedist1, unique values: 162, nan values: 806, sample_values: ['R6' 'R4-1' 'R3-2']
# feature: splitzone, unique values: 2, nan values: 806, sample_values: ['N' 'Y']
# feature: irrlotcode, unique values: 2, nan values: 397, sample_values: ['N' 'Y']
# feature: zonemap, unique values: 129, nan values: 787, sample_values: ['6C' '31A' '23B']
# feature: block, unique values: 13915, zero counts: 1, nan values: 0, sample_values: [ 3717 15818  6787]
# feature: lot, unique values: 2331, nan values: 0, sample_values: [64 48  7]
# feature: schooldist, unique values: 32, nan values: 2203, sample_values: [ 8. 27. 22.]
# feature: council, unique values: 51, nan values: 2417, sample_values: [18. 31. 48.]
# feature: zipcode, unique values: 208, nan values: 3327, sample_values: [10472. 11691. 11229.]
# feature: policeprct, unique values: 77, nan values: 2372, sample_values: [ 43. 101.  61.]
# feature: healthcenterdistrict, unique values: 30, nan values: 2126, sample_values: [26. 45. 35.]
# feature: healtharea, unique values: 210, nan values: 2649, sample_values: [3020. 3800. 7320.]
# feature: sanitboro, unique values: 8, nan values: 5093, sample_values: [2. 4. 3.]
# feature: sanitdistrict, unique values: 27, nan values: 5065, sample_values: [ 9. 14. 15.]
# feature: landuse, unique values: 11, nan values: 2293, sample_values: [1. 2. 4.]
# feature: proxcode, unique values: 4, zero counts: 117898, nan values: 397, sample_values: [2. 1. 3.]
# feature: lottype, unique values: 10, zero counts: 6526, nan values: 397, sample_values: [5. 3. 8.]
# feature: bsmtcode, unique values: 6, zero counts: 90124, nan values: 397, sample_values: [2. 0. 1.]
# feature: yearbuilt, unique values: 214, zero counts: 35724, nan values: 0, sample_values: [1940 1930 1910]
# feature: yearalter1, unique values: 116, zero counts: 616737, nan values: 0, sample_values: [   0 1986 1949]
# feature: yearalter2, unique values: 74, zero counts: 676051, nan values: 0, sample_values: [   0 1997 2005]
# feature: tract2010, unique values: 1328, zero counts: 3259, nan values: 0, sample_values: [   48 99802   548]

# %%
features_to_drop = ['yearalter1', 'yearalter2']
categorical_features = [f for f in categorical_features if f not in features_to_drop ]
new_train_data = train_data[categorical_features + numerical_features]

# %%
# mode imputation
categorical_data_mode = new_train_data[categorical_features].mode().iloc[0]
new_train_data.loc[:, categorical_features] = new_train_data[categorical_features].fillna(categorical_data_mode)
# mean imputation
numerical_data_mean = new_train_data[numerical_features].mean()
new_train_data.loc[:, numerical_features] = new_train_data[numerical_features].fillna(numerical_data_mean)

# %%
from category_encoders import MEstimateEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_train_data, train_data.target__office, test_size=0.33, stratify=train_data.target__office, random_state=42)

# %%
one_hot_encode_columns = []
target_encode_columns = []
for f in categorical_features:
    unique_values = new_train_data[f].unique()
    if len(unique_values) > 5:
        target_encode_columns.append(f)
    else:
        one_hot_encode_columns.append(f)
        
one_hot_encode_columns
# Out:
# ['borough', 'splitzone', 'irrlotcode', 'proxcode']

# %%
ohe = OneHotEncoder(cols=one_hot_encode_columns, )
X_train_new = ohe.fit_transform(X_train, y_train)

mee = MEstimateEncoder(cols=target_encode_columns, m=2)
X_train_new = mee.fit_transform(X_train_new, y_train)

# %%
X_test_new = ohe.transform(X_test, y_test)
X_test_new = mee.transform(X_test_new, y_test)

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train_new, y_train)
mutual_info
# Out:
# array([4.33363392e-02, 4.74282462e-03, 3.25866953e-03, 3.19113796e-02,
#        6.46647827e-03, 7.29128768e-03, 5.56843565e-03, 1.03574070e-02,
#        9.87824122e-02, 1.51698388e-02, 9.44439745e-02, 8.82367115e-03,
#        6.23548585e-03, 1.41289437e-02, 2.19750980e-03, 7.34602697e-03,
#        6.33410397e-03, 6.78099355e-03, 6.62898747e-03, 7.49794410e-03,
#        5.43061602e-03, 2.00654268e-02, 8.51626546e-03, 2.82690040e-02,
#        4.08822224e-02, 1.63214125e-02, 1.62019148e-02, 9.39948622e-03,
#        5.37941823e-02, 3.47386579e-02, 6.93551043e-03, 5.96561482e-03,
#        1.74236012e-04, 4.09233932e-03, 8.86354565e-03, 2.01877236e-02,
#        1.32476557e-02, 3.13623584e-02, 4.43337111e-03, 3.68668472e-04,
#        1.06149213e-03, 2.85336257e-05, 3.75254291e-04, 2.32104523e-02,
#        3.99568254e-02, 3.03718049e-03, 5.91229964e-03, 2.64834542e-02,
#        1.07037287e-02, 1.02258247e-02, 1.67049839e-02, 1.52916855e-02,
#        4.44765570e-03, 4.58359991e-03, 7.05156612e-03, 2.73420387e-03,
#        2.07732483e-03])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train_new.columns
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectKBest
# Now we Will select the  top n features
sel_cols = SelectKBest(mutual_info_classif, k=25)
sel_cols.fit(X_train_new, y_train)
X_train_new.columns[sel_cols.get_support()]
# Out:
# Index(['borough_1', 'borough_4', 'zonedist1', 'splitzone_1', 'splitzone_2',
#        'irrlotcode_1', 'block', 'sanitboro', 'landuse', 'proxcode_1',
#        'proxcode_2', 'proxcode_3', 'proxcode_4', 'lottype', 'bsmtcode',
#        'comarea', 'resarea', 'officearea', 'numbldgs', 'numfloors', 'lotdepth',
#        'bldgfront', 'bldgdepth', 'assessland', 'assesstot'],
#       dtype='object')

# %%
selected_cols = X_train_new.columns[sel_cols.get_support()]
X_train_new = X_train_new[selected_cols]
X_test_new = X_test_new[selected_cols]

# %%
num_true_records = sum(y_train == True) * 1
num_false_records = sum(y_train == False)
num_false_records
# Out:
# 456797

# %%
num_classifiers = num_false_records // num_true_records
false_records_index = y_train.index[y_train == False].tolist()
true_records_index = y_train.index[y_train == True].tolist() 

classifiers = []
accuracies = []
for i in range(num_classifiers):
    from_ = i * num_true_records
    to_ = (i * num_true_records) + num_true_records
    false_train_index = false_records_index[from_: to_]
    
    X_ = X_train_new.loc[false_train_index + true_records_index]
    y_ = y_train.loc[false_train_index + true_records_index]
    idx = np.random.permutation(X_.index)
    X_.reindex(idx)
    y_.reindex(idx)
    clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
    clf.fit(X_, y_)
    classifiers.append(clf)
    
    y_hat = clf.predict(X_test_new)
    accuracies.append(accuracy_score(y_test.astype(int), y_hat.astype(int)))

# %%
def predict(classifiers, X_test):
    f = lambda y: -1 if y == 0 else 1
    f_inv = lambda y: 0 if y < 0 else 1
    prediction = np.zeros(len(X_test))
    
    for clf in classifiers:
        y_hat = clf.predict(X_test).astype(int)
        prediction = prediction + np.array(list(map(f, y_hat)))
        
    return np.array(list(map(f_inv, prediction)))
    
y_hat = predict(classifiers, X_test_new)

# %%
print(accuracy_score(y_test.astype(int), y_hat.astype(int)))
cm = confusion_matrix(y_test, y_hat)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.show()
# Out:
# 0.9641761303519786
